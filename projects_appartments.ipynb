# %% [markdown]
# <div style="border:solid green 2px; padding: 20px">
#
# <b>Дмитрий, привет!</b> Мы рады тебя видеть на территории код-ревьюеров 😎. Ты проделал большую работу над проектом, но давай познакомимся и сделаем его еще лучше! У нас тут своя атмосфера и несколько правил:
#
#
# 1. Меня зовут Александр Матвеевский. Я работаю код-ревьюером, моя основная цель — не указать на совершенные тобою ошибки, а поделиться своим опытом и помочь тебе стать дата-специалистом.
# 2. Общаемся на ты.
# 3. Если хочешь написать, спросить - не нужно стесняться. Только выбери свой цвет для комментария.
# 4. Это учебный проект, тут можно не бояться сделать ошибку.
# 5. У нас с тобой 6 попыток для сдачи проекта.
# 6. Let's Go!
#
# ---
#
# Я буду красить комментарии цветом, пожалуйста, не удаляй их:
#
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий нужно исправить обязательно, он критически влияет на удачное выполнение проекта.
# </div>
#
# ---
#
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Такой комментарий является рекомендацией или советом. Можешь использовать их на своё усмотрение.
# </div>
#
# ---
#
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Такой комментарий  говорит о том, что было сделано что-то качественное и правильное =)
# </div>
#
# ---
#
# Предлагаю работать над проектом в диалоге: если ты что-то меняешь в проекте или отвечаешь на мои комментарии — пиши об этом. Мне будет легче отследить изменения, если ты выделишь свои комментарии:
#
# <div class="alert alert-info"> <b>Комментарии студента:</b> Например, вот так.</div>
#
# Всё это поможет выполнить повторную проверку твоего проекта оперативнее. Если будут какие-нибудь вопросы по моим комментариям, пиши, будем разбираться вместе :)
#
# ---

# %% [markdown]
# # Исследование объявлений о продаже квартир
#
# В вашем распоряжении данные сервиса Яндекс Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктах за несколько лет. Вам нужно научиться определять рыночную стоимость объектов недвижимости. Для этого проведите исследовательский анализ данных и установите параметры, влияющие на цену объектов. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта и других объектов — эти данные автоматически получены из геосервисов. Количество парков и водоёмов также заполняется без участия пользователя.

# %% [markdown]
# **Цель исследования:**
# 1. Определить рыночную стоимость объектов недвижимости;
# 2. Установить, какие факторы влияют на ценообразование стоимости квартир;
# 3. Установить, какие значения являются аномальными для объвлений в системе.
#
# **Ход исследования:**
#
# 1. Обзор данных;
# 2. Предобработка данных (поиск пропусков, их заполнение, проверка на дубликаты);
# 3. Исследование длительности закрытия объявлений;
# 4. Исследование факторов, влияющих на стоимость квартир в СПб и ЛО;
# 5. Исследование наиболее популярных для продажи/покупки квартир населенных пунктов;
# 6. Исследование стоимости жилья в Санкт-Петербурге;
# 7. Общий вывод.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Супер, старайся, пожалуйста, придерживаться этой стратегии в дальнейших проектах =)
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
#
# Отличная практика - расписывать цель и основные этапы своими словами (этот навык очень поможет на фильнальном проекте). Хорошо было бы добавить ход и цель исследования. Вот мой личный пример:
#
# ![image.png](attachment:image.png)
#
#
# ---
#
# `PS: из-за этого сообщения может часто возникать ошибка в ноутбуке`. Если мешает, можешь удалить данный комментарий
# </div>

# %% [markdown]
# ### Откройте файл с данными и изучите общую информацию

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/datasets/real_estate_data.csv', sep='\t')

# %%
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00  2019-03-07T00:00:00      3
# 1             7   3350000.0       40.40  2018-12-04T00:00:00      1
# 2            10   5196000.0       56.00  2015-08-20T00:00:00      2
# 3             0  64900000.0      159.00  2015-07-24T00:00:00      3
# 4             2  10000000.0      100.00  2018-06-19T00:00:00      2
# 5            10   2890000.0       30.40  2018-09-10T00:00:00      1
# 6             6   3700000.0       37.30  2017-11-02T00:00:00      1
# 7             5   7915000.0       71.60  2019-04-18T00:00:00      2
# 8            20   2900000.0       33.16  2018-05-23T00:00:00      1
# 9            18   5400000.0       61.00  2017-02-26T00:00:00      3
#
#    ceiling_height  floors_total  living_area  floor is_apartment  ...  \
# 0            2.70          16.0        51.00      8          NaN  ...
# 1             NaN          11.0        18.60      1          NaN  ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.hist(figsize=(15, 20), bins=50)
plt.plot()
# Out:
# []

# %% [markdown]
# В представленном датасете 23699 объектов, 22 признака для описания объектов, 17 из них - числовые. Сразу отметим, что есть достаточно большое число объявлений без фотографий. В основном объявления объявления закрываются быстро, не так часто встречаются объявления, которые были вывешаны более 500 дней. Очевидных ошибок (например, отрицательных значений) нет.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
# __Комментарий от ревьюера №1__
#
# Отлично! Первый взгляд на данные есть

# %% [markdown]
# ### Выполните предобработку данных

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          2775 non-null   object
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               12180 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# Для наглядного отображения применим следующий метод

# %%
pd.DataFrame(round(data.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_f7209_row0_col0,#T_f7209_row1_col0,#T_f7209_row2_col0,#T_f7209_row3_col0,#T_f7209_row4_col0,#T_f7209_row6_col0,#T_f7209_row8_col0,#T_f7209_row10_col0,#T_f7209_row11_col0,#T_f7209_row14_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_f7209_row5_col0{
#             background-color:  #cdd9ec;
#             color:  #000000;
#         }#T_f7209_row7_col0{
#             background-color:  #5673e0;
#             color:  #000000;
#         }#T_f7209_row9_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_f7209_row12_col0{
#             background-color:  #5e7de7;
#             color:  #000000;
#         }#T_f7209_row13_col0{
#             background-color:  #ead4c8;
#             color:  #000000;
#         }#T_f7209_row15_col0,#T_f7209_row16_col0,#T_f7209_row17_col0,#T_f7209_row19_col0{
#             background-color:  #90b2fe;
#             color:  #000000;
# ...

# %% [markdown]
# <div class="alert alert-info">
# <b>Комментарии студента:</b>
#     Большое спасибо за метод! Возьму на вооружение</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Рад поделиться ^^

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Проверить колличество пропусков в % можно вот так:
#
#
#     pd.DataFrame(round(df.isna().mean()*100,)).style.background_gradient('coolwarm')

# %% [markdown]
# Пропуски встречаются в следующих столбцах:
# * апартаменты (булев тип)
# * расстояние до ближайшего парка
# * расстояние до ближайшего водоёма
# * количество балконов
# * высота потолоков
# * расстояние до центра города
# * расстояние до ближайшего аэропорта
# * количество парков на расстоянии до 3000 м
# * количество водоёмов на расстоянии до 3000 м
# * жилая площадь
# * площадь кухни
# * сколько дней было размещено объявление
# * количество этажей
#
# Больше всего пропусков в столбце апартаменты. Скорее всего, это связано с тем, что данное поле указывали только владельцы апартементов, поэтому можно вместо пропусков поставить значение 0 (False).
# Также большой пласт пропусков встречается в столбцах, описывающих расстояние до чего-либо (парки, водоёмы, аэропорты, центр города). Эти столбцы формировались на основе геоданных, что исключает человеческий фактор при заполнении данных. Можно предположить, что в случаях с пропусками данных искомые объекты находились на очень большом расстоянии или данные просто не подгрузились. Можно заполнить пропуски на основе расстояния населенного пункта до города или аэропрота (парки и водоёмы заполнить будет уже затруднительно). Однако в силу разнообразия пропусков в населенных пунктах это сделать не удастся.
# Количество парков, количество водоёмов тоже имеют достаточно большой процент пропусков. Скорее всего, это тоже связано с тем, что парки не были найдены, но по какой-то причине не было указано число 0. Поэтому данный вид пропусков можно заменить на 0.
# Достаточно большой процент пропусков есть и в информации, касающейся самой квартиры. Если продавец не указал число балконов, то, скорее всего, в его квартире их нет. Такие пропуски можно заменить на число 0. Такие данные как общее число этажей, жилая площадь, площадь кухни достаточно трудно заполняемы, поэтому эти пропуски есть смысл отставить, а не заполнять недостоверными данными.

# %%
#заменим пропуски в столбце is_apartment
data['is_apartment'] = data['is_apartment'].fillna(value=False)

# %%
#заменим пропуски в столбцах с количеством объектов в округе
data['ponds_around3000'] = data['ponds_around3000'].fillna(value=0)
data['parks_around3000'] = data['parks_around3000'].fillna(value=0)

# %%
#заменим пропуски в столбце balcony
data['balcony'] = data['balcony'].fillna(value=0)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Согласен, если пропуск - вероятнее всего балкон отсутствует

# %%
#Проверим, все ли пропуски были заполнены, также проверим тип данных в столбцах
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  object
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  float64
#  14  locality_name         23650 non-null  object
# ...

# %% [markdown]
# Все пропуски, которые было запланировано заполнить, заполнены. Также заметим, что не во всех столбцах совпадает тип данных с необходимым. Например необходимо заменить:
# * В столбце first_day_exposition тип данных object на datetime
# * В столбце balcony тип данных float на int (вряд ли у кого-то есть половина балкона)
#
# В остальных столбцах изменить тип данных не представляется возможным (например, floors_total), так как там присутствуют пропуски (NaN), который относится к типу float64.

# %%
#Заменим тип данных float на int в столбце balcony
data['balcony'] = data['balcony'].astype('int')

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   total_images          23699 non-null  int64
#  1   last_price            23699 non-null  float64
#  2   total_area            23699 non-null  float64
#  3   first_day_exposition  23699 non-null  datetime64[ns]
#  4   rooms                 23699 non-null  int64
#  5   ceiling_height        14504 non-null  float64
#  6   floors_total          23613 non-null  float64
#  7   living_area           21796 non-null  float64
#  8   floor                 23699 non-null  int64
#  9   is_apartment          23699 non-null  bool
#  10  studio                23699 non-null  bool
#  11  open_plan             23699 non-null  bool
#  12  kitchen_area          21421 non-null  float64
#  13  balcony               23699 non-null  int64
# ...

# %% [markdown]
# Были преобразованы все типы данных в столбцах, где это возможно (и нужно). Также были заменены пропуски в данных.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Столбцы имеют корректный тип данных

# %% [markdown]
# Рассмотрим уникальные значения столбца locality_name на наличие дубликатов (т.к. это едиснтвенный столбец со строковым типом данных)

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %% [markdown]
# При первом рассмотрении в глаза бросаются одинаковые названия с разным написанием е и ё (посёлок и поселок). Уберём сначала эти дубликаты

# %%
data['locality_name'] = (
    data['locality_name']
    .str.replace('ё', 'е')
)

# %%
#заменним менее очевидные варианты
data['locality_name'] = (
    data['locality_name']
    .replace(['Мурино', 'поселок Мурино'], 'Мурино', regex=True).
    replace('деревня Кудрово', 'Кудрово', regex=True).
    replace(['городской поселок Федоровское', 'деревня Федоровское'], 'Федоровское', regex=True).
    replace(['поселок городского типа Мга', 'городской поселок Мга'], 'Мга', regex=True).
    replace('поселок Любань', 'Любань', regex=True).
    replace('поселок при железнодорожной станции Вещево','поселок станции Вещево', regex=True).
    replace('поселок городского типа Назия', 'городской поселок Назия', regex=True).
    replace('поселок городского типа Рябово', 'поселок Рябово', regex=True)
)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Совет на будущие работы `(в этом проекте этот метод не нужен)`: обычно в датафреймах содержатся данные за несколько лет. Важно выбрать корректный метод для вычленения месяца, иначе месяца разных годов могут стать одним месяцем. Обрати внимание на метод astype('datetime64[M]'). Для его использования не нужно обращаться к pd.DatetimeIndex.
#
# Вот хорошая статья на этот счёт:
#
#      https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html
#
#     и
#
#     https://www.sharpsightlabs.com/blog/pandas-astype/
# </div>

# %% [markdown]
# Таким образом были убраны наиболее очевидные дубликаты в данных.

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'поселок Шушары', 'городской поселок Янино-1',
#        'поселок Парголово', 'Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'Федоровское',
#        'Выборг', 'Кронштадт', 'Кировск', 'деревня Новое Девяткино',
#        'поселок Металлострой', 'поселок городского типа Лебяжье',
#        'поселок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'поселок Аннино',
#        'поселок городского типа Ефимовский', 'поселок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
#        'Красное Село', 'поселок Понтонный', 'Сясьстрой', 'деревня Старая',
# ...

# %% [markdown]
# Проведём проверку на явные дубликаты

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Таким образом, можно считать, что в данных не осталось явных дубликатов.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
# Отсутствует проверка на явные дубликаты, поправишь, пожалуйста?

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Проверку совершил, всё сходится.</div>

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №2__
#
# Проверка на явные дубликаты - основа предобработки данных

# %% [markdown]
# Была проведена предобработка данных:
# * заполнены пропуски в столбцах is_apartment, balcony, parks_around3000, ponds_around3000;
# * изменён тип данных в столбцах balcony, first_day_exposition;
# * произведена замена и удаление дубликтов в столбце locality_name.

# %% [markdown]
# ### Добавьте в таблицу новые столбцы

# %% [markdown]
# 3.1. Добавить столбец с ценой одного квадратного метра $\left( \frac{руб}{м^2} \right)$.

# %%
data['average_cost'] = (data['last_price']/data['total_area']).round(2)

# %% [markdown]
# 3.2. Добавить столбец с днём публикации объявления (0 — понедельник, 1 — вторник и так далее)

# %%
data['weekday'] = data['first_day_exposition'].dt.weekday

# %% [markdown]
# 3.3. Добавить столбец с месяцем публикации объявления

# %%
data['month'] = data['first_day_exposition'].dt.month

# %% [markdown]
# 3.4. Добавить столбец с годом публикации объявления

# %%
data['year'] = data['first_day_exposition'].dt.year

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Совет на будущие работы `(в этом проекте этот метод не нужен)`: обычно в датафреймах содержатся данные за несколько лет. Важно выбрать корректный метод для вычленения месяца, иначе месяца разных годов могут стать одним месяцем. Обрати внимание на метод astype('datetime64[M]'). Для его использования не нужно обращаться к pd.DatetimeIndex.
#
# Вот хорошая статья на этот счёт:
#
#      https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.astype.html
#
#     и
#
#     https://www.sharpsightlabs.com/blog/pandas-astype/
# </div>

# %% [markdown]
# 3.5. Добавить столбец с типом этажа квартиры ('первый', 'последний', 'другой')

# %%
#напишем функцию для категоризации данных
def categorize_floor(row):
    try:
        floor = row[8]
        floors_total = row[6]
        if floor == 1:
            return 'первый'
        elif floor == floors_total:
            return 'последний'
        return 'другой'
    except:
        pass

# %%
data['floor_category'] = data.apply(categorize_floor, axis=1)

# %% [markdown]
# Проверим, что функция работает корректно. Для этого выведем уникальные значения нового столбца, чтобы проверить, что все вычисления верны.

# %%
data[['floors_total', 'floor', 'floor_category']].head(20)
# Out:
#     floors_total  floor floor_category
# 0           16.0      8         другой
# 1           11.0      1         первый
# 2            5.0      4         другой
# 3           14.0      9         другой
# 4           14.0     13         другой
# 5           12.0      5         другой
# 6           26.0      6         другой
# 7           24.0     22         другой
# 8           27.0     26         другой
# 9            9.0      7         другой
# 10          12.0      3         другой
# 11           5.0      4         другой
# 12           5.0      5      последний
# 13           5.0      5      последний
# 14           6.0      1         первый
# 15          14.0      5         другой
# 16           5.0      1         первый
# 17          17.0      7         другой
# 18           5.0      2         другой
# 19          16.0      8         другой

# %% [markdown]
# Функция работает корректно.

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Хорошо бы проверить функцию, вывев уникальные значения нового столбца

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Немного по-другому сделал проверку, как показалось, так можно выявить бОльший пласт ошибок</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# Лучше вот так:
#
#     df[].unique()

# %% [markdown]
# 3.6. Добавить столбец с расстояние от центра города в километрах

# %%
def distance_centre(cityCenters_nearest):
    try:
        return round(cityCenters_nearest / 1000, 0)
    except:
        pass

# %%
data['dist_to_centre'] = data['cityCenters_nearest'].apply(distance_centre)

# %%
data.head(10)
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0      108.00           2019-03-07      3
# 1             7   3350000.0       40.40           2018-12-04      1
# 2            10   5196000.0       56.00           2015-08-20      2
# 3             0  64900000.0      159.00           2015-07-24      3
# 4             2  10000000.0      100.00           2018-06-19      2
# 5            10   2890000.0       30.40           2018-09-10      1
# 6             6   3700000.0       37.30           2017-11-02      1
# 7             5   7915000.0       71.60           2019-04-18      2
# 8            20   2900000.0       33.16           2018-05-23      1
# 9            18   5400000.0       61.00           2017-02-26      3
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  ...  \
# 0            2.70          16.0        51.00      8         False  ...
# 1             NaN          11.0        18.60      1         False  ...
# ...

# %% [markdown]
# По итогам раздела в данные были добавлены столбцы, которые облегчат работу по анализу данных и помогут выявить признаки, влияющие на покупку квартир: цена за кваратный метр, день публикации обяъвления, месяц публикации объявления, год публикации объявления, тип этажа квартиры, расстояние от центра города в километрах.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Этот раздел выполнен качественно
# </div>

# %% [markdown]
# ### Проведите исследовательский анализ данных

# %% [markdown]
# #### Изучите перечисленные ниже параметры объектов и постройте отдельные гистограммы для каждого из этих параметров:
# * общая площадь;
# * жилая площадь;
# * площадь кухни;
# * цена объекта;
# * количество комнат;
# * высота потолков;
# * тип этажа квартиры («первый», «последний», «другой»);
# * общее количество этажей в доме;
# * расстояние до центра города в метрах;
# * расстояние до ближайшего парка.

# %%
#исследуем столбец total_area
data['total_area'].hist(bins=50, range=(0,250))
# Out:
# <AxesSubplot:>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №1__
#
# Я бы советовал сократить range и тогда мы сможем увидеть пиковые значения.
# </div>

# %% [markdown]
# Максимальное значение площади - $900 \ м^2$, минимальное - $12 \ м^2$. Согласно открытым данным, применые значения для 4-комнатных квартир находятся в пределах $170 \ м^2$. Нижняя граница - вполне реальное число.

# %%
round(data.query('total_area >= 200')['total_area'].count() / len(data) * 100, 2)
# Out:
# 0.97

# %%
data.query('total_area >= 200').loc[:,['total_area', 'rooms']].head(20)
# Out:
#       total_area  rooms
# 155        317.0      4
# 464        280.3      6
# 492        216.0      4
# 509        225.0      6
# 521        230.1      3
# 581        365.0      7
# 660        483.9      7
# 679        200.0      4
# 681        249.0      7
# 793        310.0      4
# 813        229.0      8
# 866        363.0     14
# 907        211.4      6
# 1026       310.0      5
# 1085       323.0      5
# 1187       201.0      5
# 1188       290.6      6
# 1300       280.0      5
# 1388       399.0      5
# 1494       364.0      7

# %% [markdown]
# Также заметим, что такие большие площади встречаются для квартир с большим числом комнат (до 19 комнат). Возможно, в данных так отражены частные дома с большим количеством комнат и, соответственно, с большой общей площадью. Такие данные могут быть полезны для исследования элитной недвижимости и коттеджей. Такие данные не превышают 1% от общего числа записей, что тоже согласуется с гипотезой. (на Циане такое есть https://www.cian.ru/cat.php?bedroom_total=5&deal_type=sale&engine_version=2&minarea=200&minfloorn=2&object_type%5B0%5D=1&offer_type=suburban&region=1)

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Молодец, что выводы подкрепляешь сторонними источниками

# %%
data['total_area'].describe()
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %%
#рассмотрим объявления с наиболее часто встрчаемыми значениями общей площади
data['total_area'].hist(bins=50, range=(0,200))
# Out:
# <AxesSubplot:>

# %% [markdown]
# По данным видно, что большая часть квартир находится в диапазоне $25 - 75 \ м^2$. Квартиры с большей площадью - редкость.

# %%
data['living_area'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
data['living_area'].describe()
# Out:
# count    21796.000000
# mean        34.457852
# std         22.030445
# min          2.000000
# 25%         18.600000
# 50%         30.000000
# 75%         42.300000
# max        409.700000
# Name: living_area, dtype: float64

# %% [markdown]
# Рассмотрим поближе основную массу объявлений

# %%
data['living_area'].hist(bins=50, range=(0,100))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Видны два заметных пика в районе 19 $м^2$ и $30 \ м^2$. В целом распределение жилой площади согласуется с распредлением общей площади: чем выше общая площадь, темы выше жилая площадь. Однако есть провал около 23 $м^2$, что может быть связано с наличием в данных квартир и домов с большой площадью балконов или других нежилых помещений.

# %%
data['kitchen_area'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
data['kitchen_area'].describe()
# Out:
# count    21421.000000
# mean        10.569807
# std          5.905438
# min          1.300000
# 25%          7.000000
# 50%          9.100000
# 75%         12.000000
# max        112.000000
# Name: kitchen_area, dtype: float64

# %% [markdown]
# Видим те же тенденции, общие для всех значений площади. Виден ярко выраженный пик, а с увеличением или уменьшением этой величины количество объектов уменьшается. Явных аномальных значений нет.

# %%
data['last_price'].hist(bins=50, range=(400000,15000000))
# Out:
# <AxesSubplot:>

# %%
data['last_price'].describe()
# Out:
# count    2.369900e+04
# mean     6.541549e+06
# std      1.088701e+07
# min      1.219000e+04
# 25%      3.400000e+06
# 50%      4.650000e+06
# 75%      6.800000e+06
# max      7.630000e+08
# Name: last_price, dtype: float64

# %% [markdown]
# Опять же наблюдается явный пик в районе 4 млн. рублей за квартиру. Есть более дорогие, есть менее, однако минимум, который встрчается - 12190 рублей. Вряд ли за столько продают квартиру, скорее всего, владелец хотел подать объявление в раздел аренды, но перепутал. Процент таких данных совершенно маленький и не влияет на данные.

# %%
data['rooms'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
data['rooms'].describe()
# Out:
# count    23699.000000
# mean         2.070636
# std          1.078405
# min          0.000000
# 25%          1.000000
# 50%          2.000000
# 75%          3.000000
# max         19.000000
# Name: rooms, dtype: float64

# %% [markdown]
# Видно, что больше всего онокомнатынх квартир, также большое количество двухкомнатных квартир. По мере увеличения комнат предложений становится всё меньше. Есть также небольшое количество объявлений с 0 комнат. Судя по сайту Яндекс.Недвижимость, при создании объявления можно указать количество комнат или "Студия". Значит, 0 комнат эквивалентно варианту "Студия". Проверим это с использованием столбца studio

# %%
print('Квартир с 0 комнат', len(data.query('rooms == 0')))
print('Квартир студий', data['studio'].sum())
# Out:
# Квартир с 0 комнат 197
# Квартир студий 149

# %%
data.query('rooms == 0 and ~studio').head(59)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 349               4   2320000.0       25.00           2017-09-27      0
# 508               0   3375000.0       34.40           2017-03-28      0
# 780               9   2600000.0       26.10           2018-02-20      0
# 839              14   1900000.0       35.00           2017-04-14      0
# 946               5   2200000.0       23.00           2016-09-27      0
# 1574              0   2200000.0       22.00           2017-11-03      0
# 1625              7   1980000.0       23.98           2018-02-01      0
# 2532              5   3500000.0       27.10           2018-02-01      0
# 3019             18   2100000.0       24.00           2017-11-10      0
# 4115              7   2600000.0       24.00           2018-02-01      0
# 4437             10   3200000.0       25.00           2017-10-16      0
# 4683              2   3650000.0       35.00           2018-02-01      0
# ...

# %% [markdown]
# Видно, что в целом, отсутствие флага studio, как правило, ошибка. Есть уникальные значения, например, 0 комнат в квартире 371 кв.м., но в целом это не должно влиять на данные критично. А удаление данных может плохо сказаться на результате исследования.

# %%
data['ceiling_height'].hist(bins=100, range=(0,10))
# Out:
# <AxesSubplot:>

# %%
data['ceiling_height'].describe()
# Out:
# count    14504.000000
# mean         2.771499
# std          1.261056
# min          1.000000
# 25%          2.520000
# 50%          2.650000
# 75%          2.800000
# max        100.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Видно, что большая часть значений расположилась в диапазоне от 2 до 4 метров. Минимальное значение - 1 м, что маловероятно. Максимум - 100 м, что тоже очень маловероятно. Скорее всего большие значения - это ошибки при внесении данных (32 м - это 3.2 м и т.д.). Всё, что больше 15 м, будем считать ошибкой и уменьшать в 10 раз.

# %%
data.loc[data['ceiling_height'] > 15, 'ceiling_height'] /= 10

# %%
data['ceiling_height'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
data['ceiling_height'].describe()
# Out:
# count    14504.000000
# mean         2.729608
# std          0.319850
# min          1.000000
# 25%          2.510000
# 50%          2.650000
# 75%          2.800000
# max         14.000000
# Name: ceiling_height, dtype: float64

# %% [markdown]
# Данное преобразование уменьшило стандартное отклонение (1.3 м до 0.3 м), при этом мало повлияло на центральные меры (медиану и среднее).

# %%
data['floor_category'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# Ожидаемо, чаще всего встречается варинат "другой". "Первый" и "последний" встрчаются гораздо реже и примерно одинаково, но всё же квартиры на псоледних этажах продают немного чаще.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Полученные данные соответствуют реалиям
# </div>

# %%
data['floors_total'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
data['floors_total'].describe()
# Out:
# count    23613.000000
# mean        10.673824
# std          6.597173
# min          1.000000
# 25%          5.000000
# 50%          9.000000
# 75%         16.000000
# max         60.000000
# Name: floors_total, dtype: float64

# %% [markdown]
#  Минимум - 1 этаж, что очевидно. Максимум - 60 этажей (видимо, уже продают квартиры в Лахта-центре, хотя маловато этажей тогда).
#  Рассмотрим подробнее основную массу данных.

# %%
data['floors_total'].hist(bins=100, range=(0,30))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Чаще всего встрчаются объявления о продаже квартир в 5-этажках. Далее - 9-этажках, 12- и 16-этажках и снова пик на 25-этажках. Скорее всего, это типовые застройки на территории Ленинградской области, что объясняет такую встречаемость

# %%
data['cityCenters_nearest'].hist(bins=50)
# Out:
# <AxesSubplot:>

# %%
data['cityCenters_nearest'].describe()
# Out:
# count    18180.000000
# mean     14191.277833
# std       8608.386210
# min        181.000000
# 25%       9238.000000
# 50%      13098.500000
# 75%      16293.000000
# max      65968.000000
# Name: cityCenters_nearest, dtype: float64

# %% [markdown]
# Скорее всего, речь идёт о расстоянии до центра Санкт-Петербурга. Видно, что продают квартиры в городе (расстояние до 17 км) и в пригороде. Также есть пик в 30 км от центра города (Пушкин, Колпино, Петергоф, Яхья, Кронштадт и другие), менее явный пик в 50 км  или около того (на этом расстоянии находятся Зеленогорск, Тосно, Гатчина и т.д.)

# %%
data['parks_nearest'].hist(bins=100)
# Out:
# <AxesSubplot:>

# %%
data['parks_nearest'].describe()
# Out:
# count    8079.000000
# mean      490.804555
# std       342.317995
# min         1.000000
# 25%       288.000000
# 50%       455.000000
# 75%       612.000000
# max      3190.000000
# Name: parks_nearest, dtype: float64

# %% [markdown]
# Есть квартиры, находящиеся буквально около парка, а есть квартиры, где до парка идти минут 30. Возможно, такое число пропусков связано с удалением от городской застройки (деревни, пгт и т.д.), где нет парков

# %% [markdown]
# **Вывод:** Аномальные значения есть везде: где-то они объясняются особенностями рынка, а где-то это ошибки пользователей, например, если говорить о высоте потолков.
# Общий портрет продаваемой квартиры можно описать примерно следующим образом: это 2-комнатная квартира общей полщадью примерно 50 кв.м. с жилой площадью примерно 30 кв м, без балкона. Как правило, располагается не на первом и не на последнем этаже, стоимость квартиры примерно 4 млн. руб. Однокомнатные квартиры имеют площадь чуть меньше - примерно 30 кв.м, жилая площадь - около 19 кв.м.

# %% [markdown]
# #### Изучить, как быстро продавались квартиры (столбец days_exposition)

# %%
data['days_exposition'].hist(bins=200)
# Out:
# <AxesSubplot:>

# %%
data['days_exposition'].describe()
# Out:
# count    20518.000000
# mean       180.888634
# std        219.727988
# min          1.000000
# 25%         45.000000
# 50%         95.000000
# 75%        232.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Видно, что есть большой пласт объявлений, закрытых за очень короткий срок. Также есть объявления с достаточно большим сроком.
# Среднее значение - 180 дней, медианное - 95 дней. Большинство объявлений закрываются до 200 дней, исследуем эту область

# %%
data['days_exposition'].hist(bins=100, range=(0,200))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Присутствуют явные пики в районе 45-50 дней, 55-60 дней, 85-95 дней. Исследуем более детально эти выбросы

# %%
data['days_exposition'].hist(bins=100, range=(40,100))
# Out:
# <AxesSubplot:>

# %% [markdown]
# Итого: выбросы находятся на 45 дней, 60 дней и 90 дней. Согласно открытым данным на Яндекс.Недвижимости объявления держатся на сайте 90 дней, после чего они снимаются автоматически. Возможно, аномалии в 45 и 60 дней связаны с подоными особенностями. Так как нам необходимо выяснить среднее время успешного закрытия объявления, то для анализа нам необходимо избавиться от аномалий 45, 60 и 90 дней в силу того, что эти объявления с меньшей вероятностью можно считать успешными (скорее всего, они были закрыты автоматически и продажи не совершилось)

# %%
data.query('~(days_exposition == 45 or days_exposition == 60 or days_exposition == 90)')['days_exposition'].describe()
# Out:
# count    19980.000000
# mean       184.143794
# std        221.757454
# min          1.000000
# 25%         44.000000
# 50%        100.000000
# 75%        238.000000
# max       1580.000000
# Name: days_exposition, dtype: float64

# %% [markdown]
# Видно, что увеличились среднее значение и медиана (184 против 180 и 100 против 95), что говорит о том, что выбросы снижали среднее время продажи квартиры.

# %%
data.query('~(days_exposition == 45 or days_exposition == 60 or days_exposition == 90)')['days_exposition'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# На диаграмме размаха видно, что "усы" доходят до значения примерно 550 дней: выше - это уже аномально долгие продажи. Поэтому в целом продажи более 550 дней будем считать долгими. Аномально быстрыми будем считать продажи менее 44 дней (1 квартиль), нормальным сроком продажи будем считать от 44 дней до 238 дней, долгими будем считать от 238 дней до 550 дней.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Да, до 1.5 месяцев можно назвать быстрой продажей

# %% [markdown]
# #### Определить факторы, которые больше всего влияют на общую (полную) стоимость объекта

# %% [markdown]
# 4.3.1. Влияние общей площади на стоимость объекта

# %%
data.plot(x='total_area', y='last_price', kind='scatter', alpha=0.03, xlim=(0,200), ylim=(0,0.6e8))

data['total_area'].corr(data['last_price'])
# Out:
# 0.6536750579657242

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Здорово, что зависимость нелинейных данных рассматриваешь через тип графика scatter
# </div>

# %% [markdown]
# Коэффициент Пирсона говорит о наличии корреляции, но не такой сильной. На графике видно, что в диапазоне от 25 кв.м. до 100 кв.м. есть корреляция, при выходе за этот диапазон данные расположены более хаотично. Таким образом, общая площадь влияет на стоимость квартиры, но не так сильно.

# %% [markdown]
# 4.3.2. Влияние жилой площади на стоимость квартиры

# %%
data.plot(x='living_area', y='last_price', kind='scatter', alpha=0.03, xlim=(0,200), ylim=(0,0.2e8))

data['living_area'].corr(data['last_price'])
# Out:
# 0.5664915336952651

# %% [markdown]
# Коэффициент корреляции говорит о меньшей связи между данными, чем между общей площадью и ценой. Однако диаграмма показывает достаточно нетривиальную картину: видны явно выделяющиеся области, где квартиры с одной и той же площадью имеют диапазон цен. Общий тренд - увеличение общей стоимости жилья с увеличением жилой площади, однако говорить о явной  корреляции сложно.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Верная интерпретация значений корреляции Пирсона. Ты молодец =)
# </div>

# %% [markdown]
# 4.3.3. Влияние количества комнат на стомость жилья

# %%
pivot_table_rooms = pd.pivot_table(data=data, index='rooms', values='last_price', aggfunc=['median', 'mean', 'count'])
pivot_table_rooms.columns = ['median','mean','count']
print(pivot_table_rooms)
# Out:
#             median          mean  count
# rooms
# 0        2700000.0  3.337724e+06    197
# 1        3600000.0  3.835362e+06   8047
# 2        4770169.0  5.591605e+06   7940
# 3        6200000.0  8.179119e+06   5814
# 4        9000000.0  1.342350e+07   1180
# 5       14000000.0  2.376208e+07    326
# 6       19000000.0  3.170975e+07    105
# 7       24900000.0  5.147007e+07     59
# 8       23095000.0  5.022417e+07     12
# 9       23750000.0  3.415236e+07      8
# 10      23000000.0  2.616667e+07      3
# 11      25250000.0  2.525000e+07      2
# 12     420000000.0  4.200000e+08      1
# 14      26829500.0  2.682950e+07      2
# 15      65000000.0  6.500000e+07      1
# 16      28500000.0  2.850000e+07      1
# 19      32250000.0  3.225000e+07      1

# %% [markdown]
# Видно, что часто медиана и среднее сильно отличаются. Однако общий тренд и для одной меры, и для другой - на повышение. Что в целом логично: больше комнат - больше цена.

# %%
pivot_table_rooms[['median', 'mean']].plot(grid=True, figsize=(12, 5), xlim=(0,19))
plt.xticks([i for i in range(20)])
plt.plot()
# Out:
# []

# %% [markdown]
# Чтобы избавиться от флуктуаций, поставим фильтр на значения count в 50.

# %%
pivot_table_rooms.query('count > 50')[['median', 'mean']].plot(grid=True, figsize=(12, 5), xlim=(0,7))
plt.xticks([i for i in range(7)])
plt.plot()
# Out:
# []

# %% [markdown]
# Вывод: число комнат влияет на цену квартиру. Характер зависимости нелинейный, что говорит о сильном влиянии этого параметра (функция похожа на степенную)

# %% [markdown]
# 4.3.4. Влияние площади кухни на стомость жилья

# %%
data.plot(x='kitchen_area', y='last_price', kind='scatter', alpha=0.03, xlim=(0,200), ylim=(0,0.4e8))

data['kitchen_area'].corr(data['last_price'])
# Out:
# 0.5198690130216392

# %% [markdown]
# Корреляция есть, но не очень большая. Пока что оказывает наименьшее влияние на цену.

# %% [markdown]
# 4.3.5. Влияние типа этажа на стоимость

# %%
pivot_table_floor = pd.pivot_table(data=data, index='floor_category', values='last_price', aggfunc=['median', 'mean', 'count'])
pivot_table_floor.columns = ['median','mean','count']
print(pivot_table_floor)
# Out:
#                    median          mean  count
# floor_category
# другой          4850000.0  6.675444e+06  17446
# первый          3900000.0  4.803560e+06   2917
# последний       4300000.0  7.361025e+06   3336

# %%
pivot_table_floor[['median', 'mean']].plot(grid=True, figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='floor_category'>

# %% [markdown]
# Первые этажи пользуются наименьшей популярностью, даже цена ниже, чем у квартир на других этажах. Прочие этажи продаются за большую цену. Возможно, никто не любит, когда в их окна смотрят с улицы

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Как в песне, "первый и последний этаж не предлагать". Традиционно, квартиры на первом и последнем этажах считаются самыми неудобными для жизни и это отражается на их стоимости.
# </div>

# %% [markdown]
# 4.3.6. Влияние даты размещения на стоимость жилья

# %%
#день недели
pivot_table_weekday = pd.pivot_table(data=data, index='weekday', values='last_price', aggfunc=['median', 'mean', 'count'])
pivot_table_weekday.columns = ['median','mean','count']
print(pivot_table_weekday)

#месяц
pivot_table_month = pd.pivot_table(data=data, index='month', values='last_price', aggfunc=['median', 'mean', 'count'])
pivot_table_month.columns = ['median','mean','count']
print(pivot_table_month)

# год
pivot_table_year = pd.pivot_table(data=data, index='year', values='last_price', aggfunc=['median', 'mean', 'count'])
pivot_table_year.columns = ['median','mean','count']
print(pivot_table_year)
# Out:
#             median          mean  count
# weekday
# 0        4650000.0  6.511613e+06   3612
# 1        4730000.0  6.394233e+06   4183
# 2        4700000.0  6.627970e+06   3974
# 3        4650000.0  6.708663e+06   4295
# 4        4585000.0  6.372131e+06   4000
# 5        4555000.0  6.976804e+06   1936
# 6        4550000.0  6.246180e+06   1699
#           median          mean  count
# month
# 1      4600000.0  6.668233e+06   1500
# 2      4650000.0  6.468500e+06   2640
# 3      4650000.0  6.359275e+06   2587
# 4      4800000.0  6.737198e+06   2379
# 5      4515000.0  6.600435e+06   1274
# 6      4400000.0  6.310269e+06   1760
# 7      4650000.0  6.649337e+06   1695
# 8      4570000.0  6.350233e+06   1744
# 9      4700000.0  6.825470e+06   1981
# 10     4570000.0  6.235013e+06   2127
# 11     4700000.0  6.461363e+06   2371
# 12     4700000.0  7.011731e+06   1641
#          median          mean  count
# year
# 2014  7700000.0  1.208714e+07    137
# 2015  5350000.0  8.572833e+06   1191
# ...

# %%
pivot_table_weekday[['median', 'mean']].plot(grid=True, figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='weekday'>

# %%
pivot_table_month[['median', 'mean']].plot(grid=True, figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='month'>

# %%
pivot_table_year[['median', 'mean']].plot(grid=True, figsize=(12, 5))
# Out:
# <AxesSubplot:xlabel='year'>

# %% [markdown]
# В силу наличия выбросов лучше использовать медиану. Явных зависимостей нет, однако дороже всего квартиры выставляются во вторник, а самый "дорогой" месяц - апрель. Зависимость от года куда более явная, самые дрогие квартиры были в 2014 году. Далее тренд шёл на понижение. А с 2018 года цены на квартиры снова пошли вверх.
#
# Для владельцев выгоднее всего было продавать в апрельский вторник в 2014 году.

# %% [markdown]
# **Вывод:** наибольшее влияние на стоимость квартиры оказывает общая площадь, в меньше степени жилая площадь и площадь кухни.
# Дешевле всего стоят первые этажи, в то время как последние этажи и любые другие стоят примерно одинаково. Количество комнат влияет очень сильно на стоимость квартиры: чем больше комнат в квартире, тем она стоит дороже. Также самые дорогие квартиры выставляются в апреле, по вторникам. Самые большие цены на квартиры были в 2014 году.

# %% [markdown]
# #### Посчитать среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений

# %%
pivot_table_locality = pd.pivot_table(data=data, index='locality_name', values='average_cost', aggfunc=['mean', 'count'])
pivot_table_locality.columns = ['Средняя цена за кв.м., руб/кв.м.', 'Количество объявлений']
print(pivot_table_locality.sort_values(by='Количество объявлений', ascending=False).head(10))
# Out:
#                    Средняя цена за кв.м., руб/кв.м.  Количество объявлений
# locality_name
# Санкт-Петербург                       114849.008793                  15721
# Мурино                                 86087.512017                    590
# Кудрово                                95324.930508                    472
# поселок Шушары                         78677.364318                    440
# Всеволожск                             68654.473970                    398
# Пушкин                                103125.819377                    369
# Колпино                                75424.579112                    338
# поселок Парголово                      90175.913089                    327
# Гатчина                                68746.146515                    307
# Выборг                                 58141.909325                    237

# %% [markdown]
# **Вывод:** Наиболее популярным городом для купли/продажи квартир ожидаемо является Санкт-Петербург (отличие от ТОП2 в 30 раз). В целом наиболее популярные города находятся в окрестностях Санкт-Петербурга (являются его пригородами). Средние цены на кв.м. разнятся в достаточно широком диапазоне: наиболее дорогие (не учитывая СПб) - в Пушкине, а наименее - в Выборге.

# %% [markdown]
# <div class="alert alert-block alert-danger">✍
#
#
# __Комментарий от ревьюера №1__
#
#
# Не совсем. Тут нужно сначала найти ТОП-10 районов по кол-ву объявлений, и уже для них рассчитать среднюю цену

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Да, действительно, немного неправильно прочитал задание. Спасибо!</div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
#
#
# __Комментарий от ревьюера №2__
#
# В единственной или последней строке ячейки кода Юпитера, метод print() не обязателен, в отличии от тренажера

# %% [markdown]
# #### Выделить квартиры в Санкт-Петербурге с помощью столбца locality_name и вычислите их среднюю стоимость на разном удалении от центра:
# * учесть каждый километр расстояния, рассчитать средние цены квартир в одном километре от центра, в двух и так далее;
# * описать, как стоимость объекта зависит от расстояния до центра города;
# * построить график изменения средней цены для каждого километра от центра Петербурга.

# %%
pivot_table_spb = (data.query('locality_name == "Санкт-Петербург"').
pivot_table(index='dist_to_centre', values='last_price', aggfunc=['mean', 'count']))
pivot_table_spb.columns = ['средняя цена', 'количество']
print(pivot_table_spb)
# Out:
#                 средняя цена  количество
# dist_to_centre
# 0.0             3.144912e+07          27
# 1.0             2.120672e+07         192
# 2.0             1.778832e+07         310
# 3.0             1.112658e+07         350
# 4.0             1.330428e+07         688
# 5.0             1.449912e+07         920
# 6.0             1.533842e+07         618
# 7.0             1.477515e+07         420
# 8.0             9.957717e+06         597
# 9.0             6.950659e+06         593
# 10.0            6.504119e+06         719
# 11.0            6.250815e+06        1178
# 12.0            5.828545e+06        1605
# 13.0            6.083141e+06        1457
# 14.0            5.629101e+06        1279
# 15.0            5.884751e+06        1568
# 16.0            5.373131e+06        1265
# 17.0            5.292395e+06         883
# 18.0            5.091331e+06         261
# 19.0            5.037675e+06         157
# 20.0            5.951465e+06          49
# ...

# %%
pivot_table_spb['средняя цена'].plot(grid=True, figsize=(12, 5), xlim=(0,29), xlabel = 'расстояние до центра, км', ylabel='средняя цена квартиры, руб.')
plt.xticks([i for i in range(30)])
plt.title('Зависимость средней цены квартиры от расстояния до центра')
plt.plot()
# Out:
# []

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Отличная визуализация.

# %% [markdown]
# **Вывод:** цена квартиры постепенно снижается в радиусе трёх километров от центра. Однако потом начинает медленно подниматься, и, после 6 км, уже начинает быть всё меньше и меньше. Такой скачок в районе 4-6 км может быть связан с тем, что в этом радиусе находится Крестовский остров - один их самых дорогих райново в Петербурге. В остальном же подтверждается мнение, что самое дорогое жильё в центре города, а, уходя на окраины, мы будем встречать более дешёвое жилье.

# %% [markdown]
# ### Напишите общий вывод

# %% [markdown]
# В процессе работы была проведена предобработка данных. Были выполнены:
# * Выгрузка данных;
# * Поиск пропущенных значений и их заполнение;
# * Удаление дубликатов.
#
# Также на этом этапе были добавлены столбцы для облегчения исследования:
# * цена одного квадратного метра;
# * день публикации объявления (0 - понедельник, 1 - вторник и т. д.);
# * месяц публикации объявления;
# * год публикации объявления;
# * тип этажа квартиры (значения — «первый», «последний», «другой»);
# * расстояние до центра города в километрах.
#
# В процессе поиска пропущенных значений был заполнен столбец *is_apartment*: предполагалось, что если не указано, является ли жилплощадь апартаментами, то она ими не является. По такому же принципу был заполнены столбцы с количеством балконов, количеством парков и водоёмов поблизости.
#
# На аномалии были исследованы следующие столбцы:
# - общая площадь;
# - жилая площадь;
# - площадь кухни;
# - цена объекта;
# - количество комнат;
# - высота потолков;
# - тип этажа квартиры («первый», «последний», «другой»);
# - общее количество этажей в доме;
# - расстояние до центра города в метрах;
# - расстояние до ближайшего парка.
#
# Были устранены аномалии в столбце с высотой потолков.
# Также можно построить общий портрет продаваемых квартир: это 2-комнатная квартира общей полщадью примерно 50 кв.м. с жилой площадью примерно 30 кв м, без балкона. Как правило, располагается не на первом и не на последнем этаже, стоимость квартиры примерно 4 млн. руб. Однокомнатные квартиры имеют площадь чуть меньше - примерно 30 кв.м, жилая площадь - около 19 кв.м.
#
# Был проведен анализ дней до закрытия объявления.
# В процессе анализа было выяснено, что встречаются выбросы в районе 45, 60 и 90 дней, что обсуловлено автоматическим снятием объявлений. В среднем продажи длятся от 44 до 238 дней, аномално быстрыми являются продажи менее, чем за 44 дня, долгими считаются продажи от 238 дней до 550, а аномально долгими считаем продажи более 550 дней.
#
# Также были исследованы факторы, влияющие на цену квартиры. Исследованы следующие факторы:
#  - общая площадь;
#  - жилая площадь;
#  - площадь кухни;
#  - количество комнат;
#  - тип этажа, на котором расположена квартира (первый, последний, другой);
#  - дата размещения (день недели, месяц, год).
#
# Были сделаны следующие выводы:
# * В наибольшей степени на цену влияет общая площадь;
# * Цена возрастает от количества комнат достаточно сильно (степенная зависимость);
# * Наиболее дешёвые квартиры - на первом этаже, наиболее дорогие находтся между первым и последним этажами;
# * Самые дорогие объявления публиковались по вторникам, месяц с самыми дорогими объявлениями - апрель, с самыми дешевыми - июнь;
# * с 2014 года цены на квартиры уменьшались, рост цен начался в 2018 году.
#
# Самые популярные населенные пункты - Санкт-Петербург и его окрестности. При этом самые дорогие квартиры ожидаемо в Санкт-Петербурге.
# В самом Санкт-Петербурге стоимость жилья уменьшается при удалении от центра, однако в районе 4-6 км от центра наблюдается скачок цен, что может быть связано с расположением на этом удалении районов с элитной застройкой.
#
# Рекомендации:
# * При выгрузке данных, собираемых автоматически, проработать систему расчёта расстояний, так как в этих данных много пропусков;
# * При выгрузке данных учитывать объявления, закрытые автоматически;
# * Сосредоточить внимание на сделках, проводимых менее, чем за 44 дня, возможно, эти сделки мошинеческие;
# * Предлагать помощь в продвижении объявлений, остающимися не закрытыми более 550 дней;
# * При оценке стоимости квартиры необходимы полагаться на количество комнат, общую площадь, тип этажа, а также жилую площадь.

# %% [markdown]
# <div class="alert alert-block alert-success">✔️
#
#
# __Комментарий от ревьюера №1__
#
# Шикарный вывод и рекомендации для бизнеса. Кстати, хорошей практикой является написание в общем выводе всех твоих действий (кратко) по проекту. Ведь вывод раскрывает для заказчика всю твою проделанную работу и за что он платит деньги, даже если ему не интересен весь процесс исследования, то в отчёт он заглянет обязательно. Ты молодец!
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">📝
# Комментарий от ревьюера №1 </b>
#
#
#
# У тебя получилась очень сильная и хорошая работа. Здорово, что расчеты ты сопровождаешь иллюстрациями, а так же не забываешь про комментарии, твой проект интересно проверять.
#
# ---
#
# Нужно поправить:
#
# 1) Проверка на дубликаты
#
# 2) ТОП-10
#
#
# ----
#
#
# Если у тебя будут какие-то вопросы по моим комментариям - обязательно пиши! Буду ждать работу на повторное ревью :)</div>

# %% [markdown]
# <div class="alert alert-info"> <b>Комментарии студента:</b> Спасибо за комментарии! Постарался исправить замечания, а ценные советы взял себе в арсенал.</div>

# %% [markdown]
# <div style="border:solid blue 3px; padding: 20px">
# <div class="alert alert-block alert-success">✔️
#
#
# __Коментарий от ревьюера №2__
#
# Дмитрий, это тебе спасибо за обратную связь и классный проект ^^ Рад, что понравилось ревью
#
#
# ---
#
#
# В остальном всё чудно😊. Твой проект так и просится на github =)
#
# Поздравляю с успешным завершением проекта 😊👍
# И желаю успехов в новых работах 😊
#
# ---
#
# От себя хочу порекомендовать тебе отличную книгу про язык Python. Она очень классная (можно купить как новую, так и на Авито попадается. Вот ссылка на pdf этой книги)
#
# https://monster-book.com/avtomatizaciya-zadach-s-python
# </div>

# %% [markdown]
# **Чек-лист готовности проекта**
#
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Файл с данными открыт.
# - [x]  Файл с данными изучен: выведены первые строки, использован метод `info()`, построены гистограммы.
# - [x]  Найдены пропущенные значения.
# - [x]  Пропущенные значения заполнены там, где это возможно.
# - [x]  Объяснено, какие пропущенные значения обнаружены.
# - [x]  В каждом столбце установлен корректный тип данных.
# - [x]  Объяснено, в каких столбцах изменён тип данных и почему.
# - [x]  Устранены неявные дубликаты в названиях населённых пунктов.
# - [x]  Обработаны редкие и выбивающиеся значения (аномалии).
# - [x]  В таблицу добавлены новые параметры:
#        – цена одного квадратного метра;
#        – день публикации объявления (0 - понедельник, 1 - вторник и т. д.);
#        – месяц публикации объявления;
#        – год публикации объявления;
#        – тип этажа квартиры (значения — «первый», «последний», «другой»);
#        – расстояние до центра города в километрах.
# - [x]  Изучены и описаны параметры:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - цена объекта;
#         - количество комнат;
#         - высота потолков;
#         - тип этажа квартиры («первый», «последний», «другой»);
#         - общее количество этажей в доме;
#         - расстояние до центра города в метрах;
#         - расстояние до ближайшего парка.
# - [x]  Выполнено задание «Изучите, как быстро продавались квартиры (столбец `days_exposition`)»:
#     - построена гистограмма;
#     - рассчитаны среднее и медиана;
#     - описано, сколько обычно занимает продажа и указано, какие продажи можно считать быстрыми, а какие — необычно долгими.
# - [x]  Выполнено задание «Определите факторы, которые больше всего влияют на общую (полную) стоимость объекта». Построены графики, которые показывают зависимость цены от параметров:
#         - общая площадь;
#         - жилая площадь;
#         - площадь кухни;
#         - количество комнат;
#         - тип этажа, на котором расположена квартира (первый, последний, другой);
#         - дата размещения (день недели, месяц, год).
# - [x]  Выполнено задание «Посчитайте среднюю цену одного квадратного метра в 10 населённых пунктах с наибольшим числом объявлений»:
#     - выделены населённые пункты с самой высокой и низкой стоимостью квадратного метра.
# - [x]  Выполнено задание «Выделите квартиры в Санкт-Петербурге с помощью столбца `locality_name` и вычислите их среднюю стоимость на разном удалении от центра»:
#     -  учтён каждый километр расстояния, известны средние цены квартир в одном километре от центра, в двух и так далее;
#     -  описано, как стоимость объекта зависит от расстояния до центра города;
#     -  построен график изменения средней цены для каждого километра от центра Петербурга.
# - [x]  На каждом этапе сделаны промежуточные выводы.
# - [x]  В конце проекта сделан общий вывод.
